# %%
import pandas as pd

# %%
pd.read_csv('dataset/csv/train.csv')
# Out:
#         Unnamed: 0        ID  line_number discourse_type  \
# 0                2  24464531            2        METHODS
# 1                3  24464531            3        METHODS
# 2                4  24464531            4        METHODS
# 3                5  24464531            5        METHODS
# 4                6  24464531            6        RESULTS
# ...            ...       ...          ...            ...
# 180033      180035  24464531            7        RESULTS
# 180034      180036  24464531            8        RESULTS
# 180035      180037  24464531            9        RESULTS
# 180036      180038  24464531           10    CONCLUSIONS
# 180037      180039  24464531           11    CONCLUSIONS
#
#                                            discourse_text  total_lines
# 0       Outcome measures included pain reduction and i...           12
# 1       Pain was assessed using the visual analog pain...           12
# ...
